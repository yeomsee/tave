# %% [markdown]
# # 2.1) 나무위키 최신 변경 문서의 키워드 분석

# %%
# -*- coding: utf-8 -*-

# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # <Step1. 크롤링> : 크롤링으로 웹 데이터 가져오기

# %%
# !pip install selenium beautifulsoup4
# 그대로 실행하니 
# C:\Users\시형\AppData\Local\Temp\ipykernel_14648\3163842747.py:16: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
# driver = webdriver.Chrome(executable_path=excutable_path)  # for Windows가 나타났음

# 해결방법 1 : 위와 같이 구버전 selenium을 설치
# 해결방법 2 : selenium 최신버전에 맞춰 코드 새로 짜기
# 관련 url : https://yeko90.tistory.com/entry/%EC%85%80%EB%A0%88%EB%8B%88%EC%9B%80-%EA%B8%B0%EC%B4%88-executablepath-has-been-deprecated-please-pass-in-a-Service-object-%EC%97%90%EB%9F%AC-%ED%95%B4%EA%B2%B0-%EB%B0%A9%EB%B2%95
# ! pip install webdriver_manager
# Out:
# Requirement already satisfied: selenium in c:\anaconda\envs\pybook\lib\site-packages (4.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\anaconda\envs\pybook\lib\site-packages (4.11.1)
# Requirement already satisfied: trio-websocket~=0.9 in c:\anaconda\envs\pybook\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\anaconda\envs\pybook\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\anaconda\envs\pybook\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\anaconda\envs\pybook\lib\site-packages (from selenium) (1.26.12)
# Requirement already satisfied: soupsieve>1.2 in c:\anaconda\envs\pybook\lib\site-packages (from beautifulsoup4) (2.3.2.post1)
# Requirement already satisfied: async-generator>=1.9 in c:\anaconda\envs\pybook\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\anaconda\envs\pybook\lib\site-packages (from trio~=0.17->selenium) (1.0.0rc9)
# Requirement already satisfied: idna in c:\anaconda\envs\pybook\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: cffi>=1.14 in c:\anaconda\envs\pybook\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: outcome in c:\anaconda\envs\pybook\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\anaconda\envs\pybook\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in c:\anaconda\envs\pybook\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in c:\anaconda\envs\pybook\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: wsproto>=0.14 in c:\anaconda\envs\pybook\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\anaconda\envs\pybook\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\anaconda\envs\pybook\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\anaconda\envs\pybook\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
# import time
# from selenium import webdriver

# from selenium.webdriver.common.by import By
# from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# -----

# %%
import os # 패지키 로드
os.getcwd() # 현재 위치
set_path = 'C:/python'
os.chdir(set_path) # 절대 경로 설정

# %% [markdown]
# ### 셀레니움으로 브라우저 열기

# %%
from selenium import webdriver # 드라이버 불러오기
from bs4 import BeautifulSoup
import re

# 1. 윈도우용 크롬 웹드라이버 실행 경로 (Windows)
excutable_path = "chromedriver.exe"
# 만약 크롬드라이버를 노트북경로랑 같은 곳에 두었다면 굳이 지정하지 않아도 됨!

# 2. 크롤링할 사이트 주소를 정의.
url = "https://namu.wiki/RecentChanges"

# 3. 사이트의 html 구조에 기반하여 크롤링을 수행.
driver = webdriver.Chrome(executable_path=excutable_path)

# 4. url 접근
driver.get(url)

# %% [markdown]
# ### 자동화 방법

# %%
# ctrl + shift + I 를 이용하여 url 정보 사전에 확인하기

# %%
# 브라우저에 보이는 그대로의 html
req = driver.page_source

# BeautifulSoup(open("index.html"),"html.parser")
# "html.parser" : BeautifuㅣSoup 객체에게 "Html을 분석하라"고 명령
# 안 써도 상관은 없음
soup = BeautifulSoup(req, "html.parser") 

# soup.find(name, attrs, recursive, string, **kwargs)
# name : (태그의) 이름, attrs : 속성, .. (https://homubee.tistory.com/20 에서 확인)
# soup.find("p") : 처음 등장하는 p 태그 찾기
# soup.find_all("p") : 모든 p 태그 찾기
contents_table = soup.find(name="table")
table_body = contents_table.find(name="tbody")
table_rows = table_body.find_all(name="tr")

# find로 얻은 결과도 BeautifulSoup의 객체가 될 수 있음.
# 그래서 find를 한 결과에 또 find를 적용할 수 있다.
# 가령, table_rows = soup.find(name="table").find(name="tbody").find("tr")

# %%
# a태그의 href 속성을 리스트로 추출하여, 크롤링 할 페이지 리스트를 생성합니다.
page_url_base = "https://namu.wiki"
page_urls = [] # 크롤링 페이지 리스트 생성
for index in range(0, 10):
    first_td = table_rows[index].find_all("td")[0]
    td_url = first_td.find_all("a")
    if len(td_url) > 0:
        page_url = page_url_base + td_url[0].get("href")
        if "png" not in page_url:
            page_urls.append(page_url)

# 중복 url을 제거합니다.
page_urls = list(set(page_urls))
for page in page_urls[:5]:
    print(page)

# 크롤링에 사용한 브라우저를 종료합니다.
driver.close()
# Out:
# https://namu.wiki/w/%EC%9A%B0%EC%9E%A5%EC%82%B0%20%ED%9E%90%EC%8A%A4%ED%85%8C%EC%9D%B4%ED%8A%B8
# https://namu.wiki/w/%ED%8C%8C%EC%9D%BC:%EC%86%8C%EB%85%80%EB%A6%AC%EB%B2%84%EC%8A%A4%EB%B0%94%EB%A6%BC.jpg
# https://namu.wiki/w/%ED%8C%8C%EC%9D%BC:%EC%86%8C%EB%85%80%EB%A6%AC%EB%B2%84%EC%8A%A4%EC%8B%9C%EA%B3%84%EB%8A%94%EC%99%80%EC%B9%98.jpg
# https://namu.wiki/w/%EB%8B%A4%ED%9D%91
# https://namu.wiki/w/KBL%20%EC%BB%B5%EB%8C%80%ED%9A%8C/2022%EB%85%84

# %% [markdown]
# -----

# %% [markdown]
# ### 페이지 내 텍스트 구조 확인

# %% [markdown]
# 문서의 본문과 제목, 텍스트 데이터 가져오기

# %%
driver = webdriver.Chrome(executable_path=excutable_path) # 크롤링 수행

driver.get(page_urls[0]) # url 접근

# %%
req = driver.page_source # html

soup = BeautifulSoup(req, 'html.parser') # html 분석

contents_table = soup.find(name="div", attrs={"class":"aCNBxUDm"}) # article에서 긁어와라
title = contents_table.find_all('h1')[0] # h1 태그 찾아서 첫 번째 거 불러오기
category = contents_table.find_all('ul')[0] # ul 태그 찾아서 첫 번째 거 불러오기
content_paragraphs = contents_table.find_all(name="div", attrs={"class":"upwzFoAB"})
# 클래스 찾아내기

# <h1 title = "Picture"> 그림책 </h1>이라고 써 있다면 태그는 h1, attribute 값은 Picture

# %%
# 크롤링 할 페이지의 리스트 만들기
content_corpus_list = []

for paragraphs in content_paragraphs:
    content_corpus_list.append(paragraphs.text)
content_corpus = "".join(content_corpus_list)

print(title.text) # 제목 정보
print("\n")
print(category.text) # 카테고리
print("\n")
print(content_corpus) # 본문
# Out:
# 우장산 힐스테이트
#
#
# 강서구(서울)의 공동주택나무위키 공동주택 프로젝트대단지 아파트
#
#
# 서울특별시공동주택서울특별시공동주택 [ 펼치기 · 접기 ]자치구강남구강동구강북구강서구관악구광진구구로구금천구노원구도봉구동대문구동작구마포구서대문구서초구성동구성북구송파구양천구영등포구용산구은평구종로구중구중랑구자치구강남구강동구강북구강서구관악구광진구구로구금천구노원구도봉구동대문구동작구마포구서대문구서초구성동구성북구송파구양천구영등포구용산구은평구종로구중구중랑구단지 전경명칭우장산 힐스테이트영문 명칭Ujangsan HILLSTATE종류아파트브랜드주소서울특별시 강서구 강서로 348 (내발산동)입주2005년 5월동수40개동, 101동 ~140동층수지하 2층, 지상 15~21층세대수2,198세대 면적79㎡, 109㎡, 112㎡, 132㎡, 158㎡시공사ㅤㅤ주차대수2,780대 (세대당 1.26대)전기차 충전시설 유무존재상가동측, 서측 2개동1. 개요2. 특징 및 시설2.1. 주민시설2.2. 상업시설3. 주변환경3.1. 교통3.1.1. 지하철역3.1.2. 버스4. 관련항목서울특별시 강서구 강서로 348(舊 내발산동 657)에 위치한 규모 2198세대 면적 79.32제곱미터~158.65제곱미터로 총 40개동, 101~140동으로, 각 동은
우장산의 산책로와 양궁장, 테니스장 등 체육시설이 가까이 갖춰져 있어 주민들이 많이 이용하고 있다.서측 단지 상가 지하에는 발산홈마트가 있으며 정문쪽엔 홈플러스와 생협, 후문 쪽 동측 상가 지하에는 할인마트가 있다. 그래서 어느 쪽에 살든 무거운 짐을 끌고 다닐 필요가 없다.  북문 횡단보도 바로 앞에 스테이크와 뷔페로 유명한 VIPS가 무려 본점으로 입주해 있으며, 스타벅스 등촌점이 있다.앞단지 기준 도보 약 3분거리에 이화여자대학교 서울병원, 도보 약 5분거리에 NC백화점 강서점과 킴스마켓(식품관), 하이마트 메가스토어 발산점, 현대그룹의 가구 전문 브랜드인 현대리바트 스타일샵 강서전시장이 각기 건물 5,6층 규모로 위치하고 있다.마곡과 이어지는 발산역 사거리에 다이소가 있고, 병원, 식당 ,학원 등 각종 편의시설뿐만 아니라 기업들 역시 많이 입주해 있다. 간단히 주변 카페만 하더라도, 대방그룹 본사 건물에 2개층짜리 스타벅스 발산역사거리점이 있다. 영화관인 메가박스, 조금 더 걸어서 ...

# %%
# 크롤링에 사용한 브라우저를 종료합니다.
driver.close()

# %% [markdown]
# -----

# %% [markdown]
# ### 나무위키 최근변경 데이터 크롤링

# %%
# 크롤링한 데이터를 데이터 프레임으로 만들기 위해 준비
columns = ["title", "category", "content_text"]
df = pd.DataFrame(columns=columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 3
#       1 # 크롤링한 데이터를 데이터 프레임으로 만들기 위해 준비
#       2 columns = ["title", "category", "content_text"]
# ----> 3 df = pd.DataFrame(columns=columns)
#
# NameError: name 'pd' is not defined

# %%
# 데이터프레임 만들기
for page_url in page_urls:

    # 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
    driver = webdriver.Chrome(executable_path=excutable_path)
    driver.get(page_url) # url 접근
    
    req = driver.page_source # html
    soup = BeautifulSoup(req, "html.parser") # html 분석
    contents_table = soup.find(name="div", attrs={"class":"aCNBxUDm"}) # article 이름 불러오기
    title = contents_table.find_all("h1")[0] # h1 tag에 해당하는 attribute 값 가져오기
    
    # 카테고리 정보가 없는 경우를 확인합니다.
    if len(contents_table.find_all("ul")) > 0:
        category = contents_table.find_all("ul")[0]
    else:
        category = None
        
    content_paragraphs = contents_table.find_all(name="div", attrs={"class":"upwzFoAB"})
    content_corpus_list = []
    
    # 페이지 내 "제목" 정보에서 개행 문자를 제거한 뒤 추출합니다.
    # 만약 없는 경우, 빈 문자열로 대체합니다.
    if title is not None:
        row_title = title.text.replace("\n", " ") # 줄바꿈 >>> 빈칸으로 대체
    else:
        row_title = ""
    
    # 페이지 내 "본문" 정보에서 개행 문자를 제거한 뒤 추출합니다. 
    # 만약 없는 경우, 빈 문자열로 대체합니다.
    if content_paragraphs is not None:
        for paragraphs in content_paragraphs:
            if paragraphs is not None:
                content_corpus_list.append(paragraphs.text.replace("\n", " "))
            else:
                content_corpus_list.append("")
    else:
        content_corpus_list.append("")
        
    # 페이지 내 카테고리정보에서 “분류”라는 단어와 개행 문자를 제거한 뒤 추출합니다. 
    # 만약 없는 경우, 빈 문자열로 대체합니다.
    if category is not None:
        row_category = category.text.replace("\n", " ")
    else:
        row_category = ""
    # 모든 정보를 하나의 데이터 프레임에 저장합니다.
    row = [row_title, row_category, "".join(content_corpus_list)]
    series = pd.Series(row, index=df.columns)
    df = df.append(series, ignore_index=True)
    
    # 크롤링에 사용한 브라우저를 종료합니다.
    driver.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 2
#       1 # 데이터프레임 만들기
# ----> 2 for page_url in page_urls:
#       3
#       4     # 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
#       5     driver = webdriver.Chrome(executable_path=excutable_path)
#       6     driver.get(page_url) # url 접근
#
# NameError: name 'page_urls' is not defined

# %%
# 데이터 프레임을 출력합니다.
df.head(5)
# Out:
#                 title                              category  \
# 0          우장산 힐스테이트     강서구(서울)의 공동주택나무위키 공동주택 프로젝트대단지 아파트
# 1     파일:소녀리버스바림.jpg               파일/아이돌/버츄얼파일/버츄얼 유튜버/프로필
# 2  파일:소녀리버스시계는와치.jpg               파일/아이돌/버츄얼파일/버츄얼 유튜버/프로필
# 3                 다흑   1991년 출생유튜버애완동물 유튜버나무위키 인터넷 방송인 프로젝트
# 4      KBL 컵대회/2022년               KBL 컵대회한국프로농구/2022-23 시즌
#
#                                         content_text
# 0  서울특별시공동주택서울특별시공동주택 [ 펼치기 · 접기 ]자치구강남구강동구강북구강서구...
# 1  이 파일은 나무위키에서 제한된 한도 안에서 쓰입니다.본 이미지는 퍼블릭 도메인 혹은...
# 2  이 파일은 나무위키에서 제한된 한도 안에서 쓰입니다.본 이미지는 퍼블릭 도메인 혹은...
# 3  다흑이름다흑본명김주식성별남성생일1991년 12월 1일 (30세)혈액형O형직업브리더,...
# 4     상위 문서: KBL 컵대회 KBL 컵대회20202021 202220232024...

# %% [markdown]
# -----

# %% [markdown]
# # <Step2. 추출> : 키워드 추출

# %% [markdown]
# ### 텍스트 데이터 전처리

# %% [markdown]
# 특수문자나 외국어를 제거

# %%
# 텍스트 정제 함수 : 한글 이외의 문자는 전부 제거합니다.
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+') # 한글의 정규표현식을 나타냅니다.
    result = hangul.sub('', text) # a.sub("찾을 패턴","대체할 문자")
    return result

# %%
print(text_cleaning(df['content_text'][0]))
# Out:
# 서울특별시공동주택서울특별시공동주택  펼치기  접기 자치구강남구강동구강북구강서구관악구광진구구로구금천구노원구도봉구동대문구동작구마포구서대문구서초구성동구성북구송파구양천구영등포구용산구은평구종로구중구중랑구자치구강남구강동구강북구강서구관악구광진구구로구금천구노원구도봉구동대문구동작구마포구서대문구서초구성동구성북구송파구양천구영등포구용산구은평구종로구중구중랑구단지 전경명칭우장산 힐스테이트영문 명칭 종류아파트브랜드주소서울특별시 강서구 강서로  내발산동입주년 월동수개동 동 동층수지하 층 지상 층세대수세대 면적    시공사주차대수대 세대당 대전기차 충전시설 유무존재상가동측 서측 개동 개요 특징 및 시설 주민시설 상업시설 주변환경 교통 지하철역 버스 관련항목서울특별시 강서구 강서로  내발산동 에 위치한 규모 세대 면적 제곱미터제곱미터로 총 개동 동으로 각 동은 보통 개의 라인으로 구성되어 있다 서울에 몇 안되는 지하철 초역세권에 전체 평지로 이루어진 대단지 아파트다지난 년 구 내발산 주공아파트와 대한항공 사원아파트 아파트 세은아파트 세림아파트를 재건축하여 년 월에 준공되었다년 우장산현대홈타운으로 입주하여 현대힐스테이트 브랜드가 도입된 후 년 우장산 힐스테이트로 변경되었다발산역  번출구에서 앞단지 기준 도보로 약 분 소요되며 사이언스파크 융복합 연구소를 포함한 마곡지구가 도보 분거리에 인접하고 있다 발산역 사거리에 바로 붙어 있어 새로 조성된 마곡으로 걸어가기도 매우 쉽다는 점을 주목할 필요가 있다 심지어 평지인데다 마곡발산사거리에 웬만한 편의시설들이 대거 있기에 생활하기에 매우 편리하다 메가박
는 파스쿠치라는 카페들이 있다사실상 주변 상업시설이 발산역과 마곡역 근처에 입주한 모든 편의 상업시설이라고 봐도 무방하다마곡개발사업으로 큰 수혜를 본 아파트대단지 중 하나인 만큼 주변환경  발산 마곡역이라고 생각하면 된다마곡에 조성된 그룹의 대부분의 계열사들이 입주한 핵심 기업단지인 사이언스파크까지 도보 분 거리로 위치하여 도보 출퇴근이 가능하며 마곡 서울식물원까지 도보 분으로 우장산과 더불어 산책코스로 가능하다자차 분거리에 강서농수산물도매시장이 위치하고 있다주변환경 역시 새로 개발된 마곡과 발산역의 주변환경과 동치라고 봐도 된다 일일이 적기에 손이 아플 지경동 바로 앞에 발산역이 있어 가장 먼 뒷단지 기준 ...

# %% [markdown]
# 모든 데이터에 전처리 적용 .. appply()

# %%
# 각 피처마다 데이터 전처리를 적용합니다.
df['title'] = df['title'].apply(lambda x: text_cleaning(x))
df['category'] = df['category'].apply(lambda x: text_cleaning(x))
df['content_text'] = df['content_text'].apply(lambda x: text_cleaning(x))
df.head(5)
# Out:
#            title                          category  \
# 0     우장산 힐스테이트   강서구서울의 공동주택나무위키 공동주택 프로젝트대단지 아파트
# 1     파일소녀리버스바림               파일아이돌버츄얼파일버츄얼 유튜버프로필
# 2  파일소녀리버스시계는와치               파일아이돌버츄얼파일버츄얼 유튜버프로필
# 3            다흑   년 출생유튜버애완동물 유튜버나무위키 인터넷 방송인 프로젝트
# 4          컵대회년                       컵대회한국프로농구 시즌
#
#                                         content_text
# 0  서울특별시공동주택서울특별시공동주택  펼치기  접기 자치구강남구강동구강북구강서구관악구...
# 1  이 파일은 나무위키에서 제한된 한도 안에서 쓰입니다본 이미지는 퍼블릭 도메인 혹은 ...
# 2  이 파일은 나무위키에서 제한된 한도 안에서 쓰입니다본 이미지는 퍼블릭 도메인 혹은 ...
# 3  다흑이름다흑본명김주식성별남성생일년 월 일 세혈액형형직업브리더 유튜버가족어머니 누나배...
# 4    상위 문서  컵대회  컵대회  새마을금고  컵대회기간 년 월 일  월 일 참가팀...

# %%
# 한글을 제외한 모든 문자들이 제거

# %% [markdown]
# -----

# %% [markdown]
# ### 말뭉치(명사, 혹은 형태소 단위의 문자열 추출) 만들기

# %%
# 각 피처마다 말뭉치를 생성합니다.
title_corpus = "".join(df['title'].tolist())
category_corpus = "".join(df['category'].tolist())
content_corpus = "".join(df['content_text'].tolist())
print(title_corpus)
# Out:
# 우장산 힐스테이트 파일소녀리버스바림 파일소녀리버스시계는와치 다흑  컵대회년 파일소녀리버스예니콜 리그 오브 레전드아이템장화 키키링   괴수 목록

# %%
# tolist로 추출 후, join으로 말뭉치 생성

# %% [markdown]
# -----

# %% [markdown]
# ### konlpy를 이용한 키워드(형태소) 추출

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\anaconda\envs\pybook\lib\site-packages (0.6.0)
# Requirement already satisfied: lxml>=4.1.0 in c:\anaconda\envs\pybook\lib\site-packages (from konlpy) (4.9.1)
# Requirement already satisfied: JPype1>=0.7.0 in c:\anaconda\envs\pybook\lib\site-packages (from konlpy) (1.4.0)
# Requirement already satisfied: numpy>=1.6 in c:\anaconda\envs\pybook\lib\site-packages (from konlpy) (1.23.3)

# %%
from konlpy.tag import Okt
nouns_tagger = Okt() 
nouns = nouns_tagger.nouns(content_corpus) # 본문에서 명사 추출

from collections import Counter # 각 문자가 문자열에서 몇 번 나타나는지를 딕셔너리 형태로 알려줌

# konlpy의 형태소 분석기로 명사 단위의 키워드를 추출합니다.

count = Counter(nouns)

# 자세한 설명은 https://needjarvis.tistory.com/645

# %%
count
# Out:
# Counter({'서울특별시': 7,
#          '주택': 3,
#          '접기': 18,
#          '자치구': 2,
#          '강남구': 2,
#          '강동구': 2,
#          '강북구': 2,
#          '강서구': 5,
#          '관악구': 2,
#          '광진구': 2,
#          '구로구': 2,
#          '금천구': 2,
#          '노원구': 2,
#          '도봉구': 2,
#          '동대문구': 2,
#          '동작구': 2,
#          '마포구': 2,
#          '서대문구': 2,
#          '서초구': 2,
#          '성동구': 2,
#          '성북구': 2,
#          '송파구': 2,
#          '양천구': 2,
#          '영등포구': 2,
#          '용산구': 2,
#          '은평구': 2,
#          '종로구': 2,
#          '중구': 2,
#          '중랑구': 2,
#          '단지': 33,
#          '명칭': 9,
#          '우장산': 17,
#          '힐스테이트': 8,
#          '영문': 1,
#          '종류': 3,
#          '아파트': 25,
#          '브랜드': 9,
#          '주소': 1,
#          '강서': 20,
#          '내발산동': 3,
#          '입': 9,
#          '주년': 8,
#          '월': 68,
#          '동수': 1,
#          '층': 8,
#          '지하': 9,
#          '지상': 49,
#          '세대': 11,
#          '면적': 2,
#          '시공사': 1,
#          '주차': 1,
#          '대수': 1,
#          '전기차': 1,
#          '충전': 18,
#          '시설': 13,
#          '유무': 1,
#          '존재': 50,
#          '가동': 1,
#          '서측': 5,
#          '개': 51,
#          '개요': 6,
#          '특징': 16,
#          '및': 32,
#          '주민': 3,
#          '상업시설': 3,
#          '주변': 15,
#          '환경': 5,
#          '교통': 3,
#          '지하철역': 1,
#          '버스': 25,
#          '관련': 22,
#          '항목': 1,
#          '위치': 14,
#          '규모': 9,
#          '제곱미터': 2,
#          '총': 13,
#          '동': 1,
#          '각': 10,
#          '은': 17,
#          '보통': 5,
#          '라인': 7,
#          '구성': 5,
#          '서울': 20,
#          '몇': 9,
#          '지하철': 4,
#          '초': 19,
#          '권': 4,
#          '전체': 22,
#          '평지': 5,
#          '지난': 5,
#          '년': 127,
#          '구': 3,
#          '발산': 7,
#          '대한항공': 1,
#          '사원': 3,
#          '림': 3,
#          '재건축': 1,
#          '준공': 1,
#          '다년': 12,
#          '홈': 2,
#          '타운': 1,
#          '현대': 10,
#          '도입': 2,
#          '후': 59,
#          '변경': 12,
#          '발산역': 23,
#          '번': 760,
#          '출구': 7,
#          '앞': 38,
#          '기준': 30,
#          '도보': 13,
#          '약': 7,
#          '분': 14,
#          '소요': 1,
#          '사이언스': 1,
#          '파크': 2,
#          '융': 1,
#          '복합': 3,
#          '연구소': 1,
#          '포함': 16,
#          '마곡지구': 2,
#          '거리': 44,
#          '인접': 1,
#          '사거리': 13,
#          '바로': 22,
#          '조성': 4,
#          '마곡': 7,
#          '매우': 219,
#          '점': 23,
#          '주목': 2,
#          '필요': 9,
#          '심지어': 42,
#          '편의': 5,
#          '대거': 2,
#          '생활': 3,
#          '메가박스': 2,
#          '그룹': 10,
#          '아트': 3,
#          '센터': 3,
#          '곁': 2,
#          '상가': 12,
#          '쪽': 27,
#          '길': 5,
#          '건너편': 1,
#          '가곡': 3,
#          '초등학교': 3,
#          '명덕': 5,
#          '고교': 1,
#          '외국어': 2,
#          '고등학교': 3,
#          '병원': 12,
#          '의과대학': 1,
#          '미즈': 1,
#          '웰튼': 1,
#          '송도': 1,
#          '등': 118,
#          '중형': 1,
#          '또한': 101,
#          '병세': 1,
#          '가장': 75,
#          '멀리': 17,
#          '크게': 15,
#          '정도': 144,
#          '무척': 1,
#          '소속': 4,
#          '한의원': 1,
#          '치과': 1,
#          '이비인후과': 1,
#          '병': 1,
#          '치료': 3,
#          '수': 325,
#          '한편': 3,
#          '동쪽': 2,
#          '년도': 2,
#          '올림픽': 3,
#          '체육관': 18,
#          '스포츠월드': 3,
#          '이름': 75,
#          '개관': 1,
#          '운영': 19,
#          '수영장': 3,
#          '각종': 10,
#          '체육': 3,
#          '치룰': 1,
#          '만': 16,
#          '국제': 1,
#          '설계': 3,
#          '사양': 3,
#          '것': 162,
#          '장점': 17,
#          '때': 163,
#          '사설': 1,
#          '비': 35,
#          '만큼': 14,
#          '경계': 4,
#          '선': 14,
#          '검': 5,
#          '덕산': 2,
#          '건물': 28,
#          '채': 8,
#          '공간': 3,
#          '가까이': 9,
#          '문': 7,
#          '경사': 1,
#          '좀': 7,
#          '도로': 5,
#          '쯤': 5,
#          '진입': 4,
#          '샛길': 1,
#          '산책': 3,
#          '린': 3,
#          '영위': 1,
#          '꽤': 51,
#          '산이': 5,
#          '임': 8,
#          '불구': 19,
#          '바람': 15,
#          '상시': 1,
#          '산': 9,
#          '덤': 11,
#          '중': 93,
#          '여자': 3,
#          '중학교': 3,
#          '화곡': 1,
#          '구내': 1,
#          '명문': 1,
#          '학군': 2,
#          '공항대로': 5,
#          '폴리': 1,
#          '청담': 1,
#          '정상': 2,
#          '학원': 34,
#          '대형': 12,
#          '분포': 1,
#          '이투스': 2,
#          '재수': 3,
#          '유명': 6,
#          '국어': 2,
#          '김종길': 2,
#          '국어학': 2,
#          '그': 127,
#          '별개': 4,
#          '시간': 82,
#          '스터디': 3,
#          '카페': 9,
#          '중고': 1,
#          '교': 1,
#          '대학생': 1,
#          '공부': 1,
#          '최근': 20,
#          '개발': 28,
#          '사업': 3,
#          '일환': 1,
#          '부지': 1,
#          '배': 18,
#          '가량': 6,
#          '증축': 1,
#          '최신': 2,
#          '급식': 3,
#          '실': 5,
#          '주차장': 1,
#          '크기': 36,
#          '역시': 34,
#          '내': 21,
#          '어린이': 5,
#          '놀': 3,
#          '놀이터': 3,
#          '개보': 1,
#          '수하': 1,
#          '무려': 64,
#          '오션': 1,
#          '차': 6,
#          '일드': 1,
#          '키즈': 1,
#          '돌핀': 1,
#          '위': 40,
#          '불과': 1,
#          '거주': 2,
#          '학': 3,
#          '김포공항': 1,
#          '접근성': 2,
#          '관통': 9,
#          '연결': 5,
#          '롯데': 1,
#          '백화점': 2,
#          '고작': 3,
#          '도착': 4,
#          '다우': 1,
#          '장산': 1,
#          '친환경': 1,
#          '면서': 2,
#          '직주': 1,
#          '근접': 45,
#          '수혜': 3,
#          '그대로': 21,
#          '입지': 3,
#          '우수': 1,
#          '겸비': 3,
#          '리': 76,
#          '모델링': 55,
#          '이슈': 2,
#          '곳': 13,
#          '동측': 3,
#          '구분': 1,
#          '즉': 6,
#          '할인': 3,
#          '마트': 4,
#          '꽃집': 1,
#          '피자': 1,
#          '가게': 6,
#          '과일': 1,
#          '은행': 2,
#          '세탁소': 2,
#          '여러': 16,
#          '논술': 1,
#          '영어학원': 1,
#          '후문': 3,
#          '우현': 1,
#          '유치원': 1,
#          '식료품': 1,
#          '빵집': 1,
#          '편의점': 2,
#          '교촌치킨': 1,
#          '치킨': 2,
#          '주문': 14,
#          '중앙': 3,
#          '세': 8,
#          '수용': 2,
#          '어린이집': 3,
#          '요즘': 7,
#          '빨간색': 1,
#          '공중전화': 1,
#          '부스': 2,
#          '외': 8,
#          '가정': 3,
#          '집들이': 1,
#          '곳곳': 2,
#          '상당수': 4,
#          '주로': 40,
#          '외관': 1,
#          '종종': 13,
#          '확인': 4,
#          '옆': 6,
#          '헬스장': 1,
#          '탁구': 1,
#          '커뮤니티': 5,
#          '인': 22,
#          '자전거': 1,
#          '초록': 2,
#          '마당': 1,
#          '배드민턴': 1,
#          '장도': 1,
#          '다단': 2,
#          '법': 4,
#          '소나무': 1,
#          '단풍나무': 1,
#          '낙우송': 1,
#          '철쭉': 1,
#          '왕벚나무': 2,
#          '정원': 2,
#          '거의': 52,
#          '지나': 1,
#          '나무': 20,
#          '수형': 1,
#          '정리': 2,
#          '구경': 2,
#          '가지': 38,
#          '재미': 3,
#          '수준': 23,
#          '래서': 3,
#          '출근': 1,
#          '전': 75,
#          '새벽': 1,
#          '조깅': 1,
#          '봄': 1,
#          '길가': 1,
#          '일제': 1,
#          '벚꽃': 1,
#          '볼': 38,
#          '장관': 2,
#          '뒤': 17,
#          '덕택': 1,
#          '새소리': 1,
#          '자연': 7,
#          '산책로': 1,
#          '양궁': 1,
#          '테니스장': 1,
#          '이용': 40,
#          '측': 2,
#          '정문': 2,
#          '홈플러스': 1,
#          '생협': 1,
#          '살': 10,
#          '짐': 3,
#          '끌': 1,
#          '북문': 1,
#          '횡단보도': 1,
#          '스테이크': 1,
#          '뷔페': 1,
#          '본점': 1,
#          '스타벅스': 3,
#          '등촌': 1,
#          '이화여자대': 1,
#          '학교': 1,
#          '강': 17,
#          '서점': 1,
#          '킴스': 1,
#          '마켓': 1,
#          '품관': 1,
#          '하이마트': 1,
#          '메가스토어': 1,
#          '가구': 1,
#          '전문': 3,
#          '대리': 3,
#          '바트': 1,
#          '스타일': 2,
#          '전시': 1,
#          '각기': 1,
#          '곡': 6,
#          '다이소': 1,
#          '식당': 2,
#          '기업': 10,
#          '대방': 1,
#          '본사': 3,
#          '개층': 1,
#          '영화관': 1,
#          '조금': 16,
#          '더': 117,
#          '식물원': 3,
#          '입구': 2,
#          '근처': 9,
#          '리저': 1,
#          '브': 2,
#          '매장': 35,
#          '아티': 1,
#          '제': 9,
#          '파스쿠치': 1,
#          '사실': 61,
#          '마곡역': 3,
#          '모든': 55,
#          '무방': 6,
#          '하나': 82,
#          '생각': 16,
#          '대부분': 48,
#          '계열': 9,
#          '핵심': 5,
#          '지인': 1,
#          '스파크': 3,
#          '출퇴근': 1,
#          '코스': 3,
#          '농': 1,
#          '수산물': 1,
#          '도매시장': 1,
#          '동치': 1,
#          '일일이': 1,
#          '적기': 2,
#          '손': 8,
#          '경동': 1,
#          '버스정류장': 2,
#          '합정': 1,
#          '홍대': 1,
#          '종로': 1,
#          '노선': 3,
#          '경기': 31,
#          '공항리무진': 1,
#          '주요': 5,
#          '지역': 12,
#          '역': 24,
#          '호선': 2,
#          '고급': 2,
#          '이내': 2,
#          '일명': 7,
#          '대장': 3,
#          '아이파크': 1,
#          '편': 23,
#          '한세상': 1,
#          '완전': 2,
#          '이동': 65,
#          '이점': 1,
#          '이용수': 1,
#          '인지': 6,
#          '에스컬레이터': 1,
#          '설치': 2,
#          '출입구': 1,
#          '대리석': 1,
#          '정류장': 8,
#          '간선': 4,
#          '지선': 4,
#          '마을': 6,
#          '심야': 6,
#          '차로': 2,
#          '시내버스': 4,
#          '경기도': 5,
#          '일반': 17,
#          '직행': 3,
#          '좌석': 2,
#          '공항버스': 2,
#          '공항': 2,
#          '노인': 3,
#          '회관': 2,
#          '로': 67,
#          '파일': 5,
#          '위키': 12,
#          '제한': 9,
#          '한도': 7,
#          '안': 38,
#          '이미지': 46,
#          '퍼블릭': 3,
#          '도메인': 3,
#          '자유': 4,
#          '저작물': 3,
#          '독점': 3,
#          '저작권': 10,
#          '다음': 21,
#          '사항': 103,
#          '참조': 5,
#          '권리자': 12,
#          '해당': 24,
#          '게시': 6,
#          '권리': 14,
#          '침해': 12,
#          '도움말': 6,
#          '문서': 284,
#          '참고': 41,
#          '메일': 6,
#          '문의': 6,
#          '업로드': 8,
#          '사용자': 7,
#          '자신': 42,
#          '행위': 6,
#          '대한': 32,
#          '법적': 7,
#          '책임': 6,
#          '부과': 6,
#          '음': 6,
#          '숙지': 6,
#          '기본': 65,
#          '정보': 21,
#          '설명': 82,
#          '출처': 3,
#          '날짜': 7,
#          '삽입': 12,
#          '저작자': 6,
#          '기타': 13,
#          '요기': 3,
#          '요': 13,
#          '본명': 1,
#          '김주식': 1,
#          '성별': 3,
#          '남성': 1,
#          '생일': 1,
#          '일': 66,
#          '혈액형': 1,
#          '직업': 2,
#          '브리': 5,
#          '유': 4,
#          '튜버': 2,
#          '가족': 2,
#          '어머니': 1,
#          '누나': 1,
#          '배우자': 1,
#          '박': 2,
#          '유나': 2,
#          '생장': 1,
#          '녀': 1,
#          '김유주': 1,
#          '생': 4,
#          '차녀': 1,
#          '김유정': 1,
#          '반려견': 1,
#          '김퍙': 5,
#          '반려': 1,
#          '묘': 1,
#          '밍꼬': 10,
#          '콘텐츠': 4,
#          '동물': 18,
#          '소개': 8,
#          '직장': 2,
#          '군포시': 3,
#          '산본동': 2,
#          '유튜브': 19,
#          '구독': 1,
#          '자만': 1,
#          '링크': 5,
#          '방송': 8,
#          '활동': 8,
#          '다흑': 31,
#          '개인': 12,
#          '더쥬': 20,
#          '영상': 27,
#          '자주': 28,
#          '등장': 77,
#          '직원': 12,
#          '희귀': 4,
#          '판매업': 1,
#          '이자': 12,
#          '자캐': 1,
#          '백설공주': 1,
#          '건': 16,
#          '토': 12,
#          '케이': 5,
#          '도마뱀붙이': 6,
#          '팬아트': 2,
#          '팝': 1,
#          '팀': 36,
#          '에픽': 3,
#          '패러디': 8,
#          '충격': 2,
#          '공포': 7,
#          '금정역': 1,
#          '부근': 2,
#          '수원역': 1,
#          '왓': 1,
#          '쥬': 1,
#          '호': 13,
#          '점도': 2,
#          '수원시': 1,
#          '팔달구': 1,
#          '산로': 1,
#          '아내': 1,
#          '쥬모': 2,
#          '현재': 57,
#          '임신': 4,
#          '육아': 1,
#          '때문': 233,
#          '판매': 3,
#          '거나': 23,
#          '곤충': 6,
#          '파충류': 10,
#          '양서류': 2,
#          '먹이': 5,
#          '주기': 7,
#          '산란': 1,
#          '부화': 3,
#          '관찰': 2,
#          '분양': 8,
#          '생물': 12,
#          '유의사항': 1,
#          '제작': 17,
#          '가끔': 19,
#          '풀밭': 1,
#          '채집': 1,
#          '수입': 7,
#          '해외': 9,
#          '방문': 3,
#          '농장': 1,
#          '리기': 7,
#          '기생충': 3,
#          '제거': 2,
#          '방법': 15,
#          '플로': 2,
#          '피': 34,
#          '테일': 2,
#          '증후군': 1,
#          '사육': 8,
#          '대상': 11,
#          '상처': 4,
#          '질병': 1,
#          '치료법': 1,
#          '뱀': 11,
#          '도마뱀': 4,
#          '중이': 11,
#          '라면': 17,
#          '꼭': 3,
#          '하자': 6,
#          '소식': 9,
#          '장단점': 60,
#          '난이도': 39,
#          '생방': 2,
#          '사용': 126,
#          '제목': 1,
#          '씨': 2,
#          '비밀친구': 1,
#          '실내': 2,
#          '동물원': 3,
#          '수족관': 1,
#          '종': 8,
#          '내용': 34,
#          '한계': 2,
#          '대해': 9,
#          '왈가': 1,
#          '왈부': 1,
#          '문제': 29,
#          '노력': 1,
#          '낫': 1,
#          '우려': 1,
#          '지점': 2,
#          '무슨': 2,
#          '마가': 1,
#          '더쥬샾': 5,
#          '진상': 1,
#          '손님': 6,
#          '온갖': 8,
#          '프로': 7,
#          '불': 8,
#          '나': 27,
#          '악플': 2,
#          '일상': 6,
#          '동물병원': 5,
#          '장임': 1,
#          '가야': 1,
#          '빌런': 3,
#          '시전': 8,
#          '무': 7,
#          '개념': 5,
#          '충': 5,
#          '고가': 4,
#          '상습범': 1,
#          '도둑': 2,
#          '분명': 2,
#          '외국': 6,
#          '불법': 2,
#          '신고': 2,
#          '변태': 1,
#          '고충': 1,
#          '전화번호': 1,
#          '전화': 3,
#          '카톡': 1,
#          '장난': 6,
#          '통': 5,
#          '이상': 32,
#          '의지': 5,
#          '트롤': 3,
#          '러': 8,
#          '신문지': 2,
#          '주머니': 2,
#          '파양': 12,
#          '주인공': 4,
#          '알': 19,
#          '페스': 1,
#          '을': 2,
#          '한국': 38,
#          '무용': 1,
#          '학생': 1,
#          '정말': 23,
#          '별의별': 1,
#          '인간': 3,
#          '군상': 1,
#          '팼다': 1,
#          '업체': 3,
#          '온': 4,
#          '폭리': 1,
#          '팔고': 4,
#          '부터': 4,
#          '시작': 23,
#          '애': 6,
#          '선동': 1,
#          '데리': 3,
#          '부모': 1,
#          '친부모': 1,
#          '수간': 1,
#          '바다악어': 1,
#          '타고': 1,
#          '등등': 5,
#          '어이': 1,
#          '엽기': 1,
#          '음모론': 1,
#          '유튜버': 4,
#          '주식': 1,
#          '파서': 2,
#          '디시': 1,
#          '부정': 2,
#          '사회': 3,
#          '인식': 14,
#          '글': 6,
#          '그냥': 24,
#          '인스타': 2,
#          '지금': 36,
#          '논란': 17,
#          '사진': 11,
#          '거': 9,
#          '하소연': 1,
#          '전부': 18,
#          '단': 19,
#          '댓글': 5,
#          '오해': 2,
#          '해명': 1,
#          '궁금증': 1,
#          '답변': 2,
#          '인터넷': 2,
#          '애호가': 1,
#          '가능성': 5,
#          '얘기': 4,
#          '기분': 2,
#          '주의': 9,
#          '업적': 4,
#          '독사': 8,
#          '원래': 22,
#          '흑형': 5,
#          '전의': 7,
#          '렙타일': 3,
#          '킹': 29,
#          '사장': 8,
#          '김': 1,
#          '모씨': 1,
#          '상주': 1,
#          '행동': 3,
#          '은근': 44,
#          '정당화': 1,
#          '사육이': 1,
#          '여론': 1,
#          '이': 157,
#          '상대로': 6,
#          '홀로': 1,
#          '장판': 2,
#          '파': 1,
#          '게': 30,
#          '아예': 19,
#          '못': 28,
#          '박아': 3,
#          '젠': 18,
#          '오진': 1,
#          '절대': 4,
#          '배척': 1,
#          '분위기': 2,
#          '발자취': 1,
#          '얼굴': 12,
#          '공개': 17,
#          '육장': 4,
#          '유리': 2,
#          '본인': 14,
#          '인스타그램': 5,
#          '가면': 7,
#          '장': 3,
#          '실제': 25,
#          '오프라인': 3,
#          '훤히': 1,
#          '적극': 8,
#          '정체': 2,
#          '흑의': 6,
#          '직접': 15,
#          '보라': 2,
#          '뜻': 6,
#          '일종': 4,
#          '홍보': 7,
#          '국내': 8,
#          '최초': 12,
#          '쌍': 3,
#          '사가': 3,
#          '얼마': 7,
#          '폐': 3,
#          '종은': 1,
#          '레드아이': 2,
#          '머드': 4,
#          '스킨크': 4,
#          '추천': 32,
#          '당장': 4,
#          '프로필': 3,
#          '해도': 18,
#          '캐리커처': 1,
#          '시행착오': 1,
#          '결과': 7,
#          '온도': 1,
#          '불빛': 1,
#          '내팽겨친': 1,
#          '듯이': 4,
#          '다그': 4,
#          '단골': 1,
#          '고객': 4,
#          '출현': 4,
#          '듯': 13,
#          '가격': 114,
#          '대도': 3,
#          '다른': 102,
#          '게코': 3,
#          '쪼물': 1,
#          '장면': 1,
#          '도': 48,
#          '왈': 2,
#          '상남자': 1,
#          '자칫하면': 2,
#          '앤더슨': 1,
#          '샐러맨더': 1,
#          '관': 3,
#          '대한민국': 1,
#          '환경부': 1,
#          '우파루파': 1,
#          '조사': 1,
#          '생김새': 3,
#          '뿐': 15,
#          '전혀': 6,
#          '종이': 3,
#          '닉': 2,
#          '흑마': 1,
#          '도사': 1,
#          '호카게': 1,
#          '단어': 1,
#          '흑인': 1,
#          '채널': 3,
#          '다흑님': 1,
#          '함': 6,
#          '남자': 1,
#          '군필': 1,
#          '마법소녀': 1,
#          '칭': 1,
#          '인사': 1,
#          '대충': 2,
#          '네': 6,
#          '저': 5,
#          '경우': 111,
#          '또': 27,
#          '옛날': 12,
#          '닉네임': 1,
#          '인기': 17,
#          '사육자': 1,
#          '숲': 1,
#          '코브라': 1,
#          '가봉북살무사': 1,
#          '뻐': 2,
#          '살무사': 1,
#          '갈등': 1,
#          '종업': 1,
#          '종사': 1,
#          '김줄스': 1,
#          '욕설': 1,
#          '허위': 1,
#          '유포': 1,
#          '고소': 3,
#          '사과문': 1,
#          '끝': 13,
#          '케어': 1,
#          '상태': 34,
#          '엉망': 1,
#          '자제': 1,
#          '요청': 3,
#          '사람': 34,
#          '수의사': 1,
#          '계속': 26,
#          '초도': 1,
#          '샵': 4,
#          '기어이': 1,
#          '유기동물': 1,
#          '장소': 2,
#          '좌표': 1,
#          '의심': 3,
#          '케이스': 2,
#          '마이': 1,
#          '트': 6,
#          '덕지덕지': 1,
#          '블루': 2,
#          '텅': 2,
#          '스킹크': 1,
#          '먼저': 7,
#          '아무': 2,
#          '다이렉트': 1,
#          '휙': 1,
#          '마리': 28,
#          '만원': 6,
#          '옮았을지': 1,
#          '가치': 6,
#          '공짜': 2,
#          '피해': 31,
#          '적도': 1,
#          '입장': 8,
#          '감안': 2,
#          '야생': 1,
#          '눈물': 1,
#          '규어': 8,
#          '사랑': 2,
#          '원피스': 4,
#          '팅': 5,
#          '개체': 5,
#          '무언가': 2,
#          '콜라': 2,
#          '곤충류': 1,
#          '업자': 1,
#          '정작': 6,
#          '장수풍뎅이': 2,
#          '사슴벌레': 1,
#          '사마귀': 4,
#          '여치': 1,
#          '대벌레': 1,
#          '제외': 28,
#          '지기': 3,
#          '모습': 74,
#          '동호': 2,
#          '사이': 13,
#          '왕사슴벌레': 3,
#          '문제점': 5,
#          '지적': 3,
#          '교잡': 1,
#          '유전자': 1,
#          '오염': 1,
#          '근친교배': 1,
#          '기간': 6,
#          '출신': 5,
#          '결혼': 1,
#          '아빠': 2,
#          '언급': 3,
#          '쥬모님': 5,
#          '이면': 5,
#          '확정': 2,
#          '날': 14,
#          '애가': 1,
#          '월경': 1,
#          '둘째': 1,
#          '내년': 1,
#          '출산': 1,
#          '예정': 18,
#          '딸': 3,
#          ...})

# %%
print(nouns)
# Out:
# ['서울특별시', '주택', '서울특별시', '주택', '접기', '자치구', '강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구', '자치구', '강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구', '단지', '명칭', '우장산', '힐스테이트', '영문', '명칭', '종류', '아파트', '브랜드', '주소', '서울특별시', '강서구', '강서', '내발산동', '입', '주년', '월', '동수', '층', '지하', '층', '지상', '층', '세대', '면적', '시공사', '주차', '대수', '세대', '전기차', '충전', '시설', '유무', '존재', '가동', '서측', '개', '개요', '특징', '및', '시설', '주민', '시설', '상업시설', '주변',
전부': 18, '해도': 18, '예정': 18, '조합': 18, '한정': 18, '잡기': 18, '비교': 18, '에너지': 18, '서비스': 18, '일본': 18, '이강': 18, '벅스': 18, '번은': 18, '우장산': 17, '멀리': 17, '장점': 17, '일반': 17, '제작': 17, '라면': 17, '논란': 17, '공개': 17, '인기': 17, '별로': 17, '방식': 17, '삭제': 17, '사건': 17, '적용': 17, '스타': 17, '활용': 17, '초보': 17, '카마': 17, '물속': 17, '가로': 17, '특징': 16, '포함': 16, '여러': 16, '조금': 16, '생각': 16, '통영': 16, '특수': 16, '개발자': 16, '가성': 16, '차이': 16, '가속': 16, '포켓몬': 16, '키키': 16, '운용': 16, '에반게리온': 16, '마키': 16, '파이어': 16, '스컬': 16, '울음소리': 16, '대쉬': 16, '도끼': 16, '주변': 15, '크게': 15, '바람': 15, '방법': 15, '직접': 15, '제일': 15, '상위': 15, '캐스터': 15, '보유': 15, '둔화': 15, '쿨감': 15, '스펙': 15, '탱커': 15, '카이': 15, '기적': 15, '도쿄': 15, '오히려': 15, '마타': 15, '밀레니엄': 15, '이펙트': 15, '브레스': 15, '고질': 15, '폭풍': 15, '멜트다운': 15, '위치': 14, '만큼': 14, '주문': 14, '권리': 14, '인식': 14, '본인': 14, '수컷': 14, '암컷': 14, '취급': 14, '진행': 14, '합계': 14, '유니버스': 14, '후반': 14, '확률': 14, '물리': 14, '도감': 14,  ...

# %% [markdown]
# -----

# %% [markdown]
# ##### 불용어 제거

# %% [markdown]
# 실질적인 의미가 없는 키워드 처리

# %%
# 한국어 약식 불용어사전 예시 파일입니다. 출처 - (https://www.ranks.nl/stopwords/korean)
korean_stopwords_path = "C:\\Users\\시형\\Desktop\\DataAnalysis\\python-data-analysis-master\\data\\korean_stopwords.txt"

# 텍스트 파일을 오픈합니다.
with open(korean_stopwords_path, encoding='utf8') as f:
    stopwords = f.readlines()
stopwords = [x.strip() for x in stopwords] # a.strip() : 공백 제거
print(stopwords[:10])
# Out:
# ['아', '휴', '아이구', '아이쿠', '아이고', '어', '나', '우리', '저희', '따라']

# %%
# 나무위키 페이지에 맞는 불용어를 추가합니다.
namu_wiki_stopwords = ['상위', '문서', '내용', '누설', '아래', '해당', '설명', '표기', '추가', '모든', '사용', '매우', '가장',
                       '줄거리', '요소', '상황', '편집', '틀', '경우', '때문', '모습', '정도', '이후', '사실', '생각', '인물', 
                       '이름', '년월']
for stopword in namu_wiki_stopwords:
    stopwords.append(stopword)

# %%
# 키워드 데이터에서 불용어를 제거합니다.
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})
print(remove_char_counter)
# Out:
# Counter({'괴수': 763, '공격': 570, '속도': 295, '체력': 290, '이전': 282, '문단': 278, '역사': 261, '고지라': 232, '고질라': 212, '스킬': 198, '대미지': 180, '게임': 165, '범위': 145, '레벨': 135, '상대': 126, '열선': 126, '유저': 116, '모션': 115, '가격': 114, '붕괴': 113, '기술': 109, '기력': 105, '토론': 104, '사항': 103, '컨트롤': 102, '합의': 102, '모델': 102, '공중': 94, '성능': 85, '방어': 85, '데미지': 82, '원거리': 81, '회복': 81, '메카': 78, '등장': 77, '히트': 77, '수영': 74, '몬스터': 73, '장화': 72, '티밍': 72, '판정': 71, '박스': 71, '너프': 70, '스텀': 70, '대미': 69, '헤이세이': 66, '이동': 65, '기본': 65, '무려': 64, '제로': 64, '울티마': 64, '장단점': 60, '기
': 18, '조합': 18, '한정': 18, '잡기': 18, '비교': 18, '에너지': 18, '서비스': 18, '일본': 18, '이강': 18, '벅스': 18, '번은': 18, '우장산': 17, '멀리': 17, '장점': 17, '일반': 17, '제작': 17, '라면': 17, '논란': 17, '공개': 17, '인기': 17, '별로': 17, '방식': 17, '삭제': 17, '사건': 17, '적용': 17, '스타': 17, '활용': 17, '초보': 17, '카마': 17, '물속': 17, '가로': 17, '특징': 16, '포함': 16, '여러': 16, '통영': 16, '특수': 16, '개발자': 16, '가성': 16, '차이': 16, '가속': 16, '포켓몬': 16, '키키': 16, '운용': 16, '에반게리온': 16, '마키': 16, '파이어': 16, '스컬': 16, '울음소리': 16, '대쉬': 16, '도끼': 16, '주변': 15, '크게': 15, '바람': 15, '방법': 15, '직접': 15, '제일': 15, '캐스터': 15, '보유': 15, '둔화': 15, '쿨감': 15, '스펙': 15, '탱커': 15, '카이': 15, '기적': 15, '도쿄': 15, '마타': 15, '밀레니엄': 15, '이펙트': 15, '브레스': 15, '고질': 15, '폭풍': 15, '멜트다운': 15, '위치': 14, '만큼': 14, '주문': 14, '권리': 14, '인식': 14, '본인': 14, '수컷': 14, '암컷': 14, '취급': 14, '진행': 14, '합계': 14, '유니버스': 14, '후반': 14, '확률': 14, '물리': 14, '도감': 14, '모티브': 14, '웨이': 14, '애니메이션': 14, '초기': 14, '패스': 14, '날기': 14, '발휘': 14, '시설': 13, '도보': 13, '사거리': 13, '종종': 13, '사이': 13, '시절': 13, '리그': 13, '해설': 13, '시스템': 13, '선택': 13, '고정': 13, '수치': 13, '기존': 13, '오버': 13, '설정': 13, '공식': 13, '포인트': 13, '반대': 13, '달성': 13, '베타': 13, '정면': 13, '플레이': 13, '덕분': 13, '스페이스': 13, '앞발': 13, '다년': 12, '변경': 12, '상가': 12, '병원': 12, '대형': 12, '지역': 12, '위키': 12, '권리자': 12,  ...

# %% [markdown]
# -----

# %% [markdown]
# # <Step3. 시각화> : 워드 클라우드 시각화

# %% [markdown]
# ### [pytagcloud 사용하기]

# %%
# !pip install pytagcloud pygame simplejson
# Out:
# Requirement already satisfied: pytagcloud in c:\anaconda\envs\pybook\lib\site-packages (0.3.5)
# Requirement already satisfied: pygame in c:\anaconda\envs\pybook\lib\site-packages (2.1.2)
# Requirement already satisfied: simplejson in c:\anaconda\envs\pybook\lib\site-packages (3.17.6)

# %%
import random
import pytagcloud
import webbrowser

# 가장 출현 빈도수가 높은 40개의 단어를 선정합니다.
ranked_tags = remove_char_counter.most_common(40)

# pytagcloud로 출력할 40개의 단어를 입력합니다. 단어 출력의 최대 크기는 80으로 제한합니다.
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)

# pytagcloud 이미지를 생성합니다. 폰트는 나눔 고딕을 사용합니다.
pytagcloud.create_tag_image(taglist, 'wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

# %%
# 생성한 이미지를 주피터 노트북상에서 출력합니다.
from IPython.display import Image
Image(filename='wordcloud.jpg')

# %% [markdown]
# -----

# %% [markdown]
# ### 나무위키 키워드 시각화

# %% [markdown]
# ##### 제목 키워드

# %%
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(title_corpus)
count = Counter(nouns)

remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})

ranked_tags = remove_char_counter.most_common(40)
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)
pytagcloud.create_tag_image(taglist, 'title_wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

Image(filename='title_wordcloud.jpg')

# %% [markdown]
# -----

# %% [markdown]
# ##### 카테고리 키워드

# %%
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(category_corpus)
count = Counter(nouns)

remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})

ranked_tags = remove_char_counter.most_common(40)
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)
pytagcloud.create_tag_image(taglist, 'category_wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

Image(filename='category_wordcloud.jpg')
